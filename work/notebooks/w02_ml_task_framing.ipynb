# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alhvirk-web/FlyRank-Ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# This is a scoring task. FlyRank needs a ranked review queue, not a single yes/no — editors work top-down through a priority list. Under the hood it's a classifier predicting probability of decline, but that probability becomes the score used to rank pages, so it behaves as scoring, not plain classification

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target: is_declining_label, set to 1 when trend_direction is "down", else 0. This comes from an observed outcome — impressions in the last 30 days vs. the previous 30 — not a rule the product team invented. I'm predicting something that actually happened, not reproducing an existing flag.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, subprocess
if not os.path.isdir("FlyRank-Ml"):
    subprocess.run(["git", "clone", "--depth", "1", "https://github.com/alhvirk-web/FlyRank-Ml"])
os.chdir("FlyRank-Ml")

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)
df["is_declining_label"].value_counts(normalize=True)
# Out:
# is_declining_label
# 1    0.542067
# 0    0.457933
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Metric: Precision@50 — of the top 50 pages the model flags, how many actually declined. This fits the real constraint: an editor can only review a limited queue each week, so what matters is accuracy at the top, not accuracy across all 30,000 pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row = one content page, aggregated over its trailing 90-day window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(df.shape)
df[["content_id", "client_id", "content_type", "impressions_90d", "trend_direction", "is_declining_label"]].head()
# Out:
# (30000, 45)
#              content_id          client_id     content_type  impressions_90d  \
# 0  content_304f48230142  client_f369cb89fc  keyword article             3803
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article            15320
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article            12581
# 3  content_331d6c4de07b  client_19581e27de  keyword article            11751
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article            19140
#
#   trend_direction  is_declining_label
# 0            down                   1
# 1            down                   1
# 2            down                   1
# 3          stable                   0
# 4            down                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# This pipeline's own hand-written baseline rule only reaches Precision@50 ≈ 0.24. That low ceiling shows decline isn't one clean signal — it's several things (word count, freshness, position, content type) interacting together, which a single if-statement can't weigh well but a model can.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
